# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

data = []
labels = []
classes = 43
cur_path = os.getcwd()

#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)

    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")

#Converting lists into numpy arrays
data = np.array(data)
labels = np.array(labels)

# %%
print(data.shape, labels.shape)
#Splitting training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#Converting the labels into one hot encoding
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)
# Out:
# (39209, 30, 30, 3) (39209,)
# (31367, 30, 30, 3) (7842, 30, 30, 3) (31367,) (7842,)

# %%
#Building the model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 50
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
model.save("my_model.h5")
# Out:
# Epoch 1/50
# 981/981 [==============================] - 47s 47ms/step - loss: 2.1553 - accuracy: 0.4666 - val_loss: 0.5534 - val_accuracy: 0.8555
# Epoch 2/50
# 981/981 [==============================] - 46s 47ms/step - loss: 0.7269 - accuracy: 0.7885 - val_loss: 0.2122 - val_accuracy: 0.9412
# Epoch 3/50
# 981/981 [==============================] - 53s 54ms/step - loss: 0.4296 - accuracy: 0.8782 - val_loss: 0.1171 - val_accuracy: 0.9660
# Epoch 4/50
# 981/981 [==============================] - 51s 52ms/step - loss: 0.3137 - accuracy: 0.9112 - val_loss: 0.0882 - val_accuracy: 0.9765
# Epoch 5/50
# 981/981 [==============================] - 52s 53ms/step - loss: 0.2467 - accuracy: 0.9291 - val_loss: 0.0794 - val_accuracy: 0.9778
# Epoch 6/50
# 981/981 [==============================] - 52s 53ms/step - loss: 0.2235 - accuracy: 0.9369 - val_loss: 0.0912 - val_accuracy: 0.9736
# Epoch 7/50
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2148 - accuracy: 0.9409 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 8/50
# 981/981 [==============================] - 55s 56ms/step - loss: 0.2165 - accuracy: 0.9411 - val_loss: 0.0624 - val_accuracy: 0.9823
# Epoch 9/50
# 981/981 [==============================] - 54s 55ms/step - loss: 0.2009 - accuracy: 0.9478 - val_loss: 0.0388 - val_accuracy: 0.9906
# Epoch 10/50
# 981/981 [==============================] - 57s 58ms/step - loss: 0.1858 - accuracy: 0.9499 - val_loss: 0.0510 - val_accuracy: 0.9856
# Epoch 11/50
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2032 - accuracy: 0.9483 - val_loss: 0.0558 - val_accuracy: 0.9851
# Epoch 12/50
# 981/981 [==============================] - 63s 64ms/step - loss: 0.1922 - accuracy: 0.9503 - val_loss: 0.0581 - val_accuracy: 0.9842
# Epoch 13/50
# 981/981 [==============================] - 62s 64ms/step - loss: 0.2111 - accuracy: 0.9481 - val_loss: 0.0402 - val_accuracy: 0.9906
# Epoch 14/50
# 981/981 [==============================] - 67s 68ms/step - loss: 0.2254 - accuracy: 0.9464 - val_loss: 0.0387 - val_accuracy: 0.9902
# Epoch 15/50
# 981/981 [==============================] - 65s 67ms/step - loss: 0.1715 - accuracy: 0.9566 - val_loss: 0.0317 - val_accuracy: 0.9920
# Epoch 16/50
# 981/981 [==============================] - 67s 68ms/step - loss: 0.1957 - accuracy: 0.9536 - val_loss: 0.0554 - val_accuracy: 0.9856
# Epoch 17/50
# 981/981 [==============================] - 62s 64ms/step - loss: 0.2279 - accuracy: 0.9450 - val_loss: 0.0828 - val_accuracy: 0.9746
# Epoch 18/50
# 981/981 [==============================] - 62s 63ms/step - loss: 0.1988 - accuracy: 0.9517 - val_loss: 0.0538 - val_accuracy: 0.9861
# Epoch 19/50
# 981/981 [==============================] - 65s 66ms/step - loss: 0.1745 - accuracy: 0.9569 - val_loss: 0.0466 - val_accuracy: 0.9893
# Epoch 20/50
# 981/981 [==============================] - 63s 64ms/step - loss: 0.1976 - accuracy: 0.9541 - val_loss: 0.0646 - val_accuracy: 0.9861
# Epoch 21/50
# 981/981 [==============================] - 62s 64ms/step - loss: 0.1787 - accuracy: 0.9570 - val_loss: 0.0434 - val_accuracy: 0.9895
# Epoch 22/50
# 981/981 [==============================] - 67s 68ms/step - loss: 0.2123 - accuracy: 0.9512 - val_loss: 0.1967 - val_accuracy: 0.9480
# Epoch 23/50
# 981/981 [==============================] - 64s 66ms/step - loss: 0.2215 - accuracy: 0.9517 - val_loss: 0.1766 - val_accuracy: 0.9538
# Epoch 24/50
# 981/981 [==============================] - 63s 64ms/step - loss: 0.2114 - accuracy: 0.9528 - val_loss: 0.0536 - val_accuracy: 0.9879
# Epoch 25/50
# 981/981 [==============================] - 64s 65ms/step - loss: 0.2125 - accuracy: 0.9539 - val_loss: 0.0521 - val_accuracy: 0.9856
# Epoch 26/50
# 981/981 [==============================] - 64s 66ms/step - loss: 0.2273 - accuracy: 0.9525 - val_loss: 0.1751 - val_accuracy: 0.9526
# Epoch 27/50
# 981/981 [==============================] - 64s 65ms/step - loss: 0.2149 - accuracy: 0.9526 - val_loss: 0.0415 - val_accuracy: 0.9918
# Epoch 28/50
# 981/981 [==============================] - 70s 71ms/step - loss: 0.2380 - accuracy: 0.9510 - val_loss: 0.0418 - val_accuracy: 0.9888
# Epoch 29/50
# 981/981 [==============================] - 66s 67ms/step - loss: 0.2071 - accuracy: 0.9545 - val_loss: 0.0599 - val_accuracy: 0.9844
# Epoch 30/50
# 981/981 [==============================] - 61s 63ms/step - loss: 0.2210 - accuracy: 0.9532 - val_loss: 0.1674 - val_accuracy: 0.9583
# Epoch 31/50
# 981/981 [==============================] - 63s 65ms/step - loss: 0.2399 - accuracy: 0.9498 - val_loss: 0.0555 - val_accuracy: 0.9862
# Epoch 32/50
# 981/981 [==============================] - 63s 64ms/step - loss: 0.2252 - accuracy: 0.9550 - val_loss: 0.0456 - val_accuracy: 0.9897
# Epoch 33/50
# 981/981 [==============================] - 61s 62ms/step - loss: 0.2469 - accuracy: 0.9505 - val_loss: 0.0538 - val_accuracy: 0.9889
# Epoch 34/50
# 981/981 [==============================] - 62s 63ms/step - loss: 0.2393 - accuracy: 0.9498 - val_loss: 0.0739 - val_accuracy: 0.9815
# Epoch 35/50
# 981/981 [==============================] - 64s 65ms/step - loss: 0.2794 - accuracy: 0.9437 - val_loss: 0.0420 - val_accuracy: 0.9897
# Epoch 36/50
# 981/981 [==============================] - 62s 63ms/step - loss: 0.2439 - accuracy: 0.9513 - val_loss: 0.0414 - val_accuracy: 0.9908
# Epoch 37/50
# 981/981 [==============================] - 60s 62ms/step - loss: 0.2275 - accuracy: 0.9506 - val_loss: 0.1209 - val_accuracy: 0.9699
# Epoch 38/50
# 981/981 [==============================] - 62s 63ms/step - loss: 0.2720 - accuracy: 0.9450 - val_loss: 0.0500 - val_accuracy: 0.9881
# Epoch 39/50
# 981/981 [==============================] - 64s 65ms/step - loss: 0.2383 - accuracy: 0.9512 - val_loss: 0.0642 - val_accuracy: 0.9842
# Epoch 40/50
# 981/981 [==============================] - 61s 62ms/step - loss: 0.2461 - accuracy: 0.9534 - val_loss: 0.0549 - val_accuracy: 0.9846
# Epoch 41/50
# 981/981 [==============================] - 63s 64ms/step - loss: 0.3405 - accuracy: 0.9304 - val_loss: 0.0395 - val_accuracy: 0.9915
# Epoch 42/50
# 981/981 [==============================] - 63s 65ms/step - loss: 0.2767 - accuracy: 0.9443 - val_loss: 0.0539 - val_accuracy: 0.9883
# Epoch 43/50
# 981/981 [==============================] - 62s 63ms/step - loss: 0.2326 - accuracy: 0.9522 - val_loss: 0.0815 - val_accuracy: 0.9791
# Epoch 44/50
# 981/981 [==============================] - 63s 64ms/step - loss: 0.2879 - accuracy: 0.9444 - val_loss: 0.0405 - val_accuracy: 0.9907
# Epoch 45/50
# 981/981 [==============================] - 59s 60ms/step - loss: 0.2774 - accuracy: 0.9461 - val_loss: 0.1133 - val_accuracy: 0.9690
# Epoch 46/50
# 981/981 [==============================] - 59s 60ms/step - loss: 0.2503 - accuracy: 0.9497 - val_loss: 0.0590 - val_accuracy: 0.9869
# Epoch 47/50
# 981/981 [==============================] - 59s 61ms/step - loss: 0.2384 - accuracy: 0.9525 - val_loss: 0.0453 - val_accuracy: 0.9898
# Epoch 48/50
# 981/981 [==============================] - 56s 57ms/step - loss: 0.2920 - accuracy: 0.9450 - val_loss: 0.0920 - val_accuracy: 0.9797
# Epoch 49/50
# 981/981 [==============================] - 54s 55ms/step - loss: 0.2744 - accuracy: 0.9496 - val_loss: 0.0485 - val_accuracy: 0.9883
# Epoch 50/50
# 981/981 [==============================] - 55s 56ms/step - loss: 0.2880 - accuracy: 0.9437 - val_loss: 0.0721 - val_accuracy: 0.9820

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
 
plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
#testing accuracy on test dataset
from sklearn.metrics import accuracy_score

y_test = pd.read_csv('Test.csv')

labels = y_test["ClassId"].values
imgs = y_test["Path"].values

data=[]

for img in imgs:
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))

X_test=np.array(data)

predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=-1)

#Accuracy with the test data
from sklearn.metrics import accuracy_score
print(accuracy_score(labels,predicted_classes ))
# Out:
# 395/395 [==============================] - 4s 9ms/step
# 0.9453681710213777

# %%
model.save('traffic_classifier_1.h5')
